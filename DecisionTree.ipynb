# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('dataset_MLproject.csv')
df.head()
# Out:
#    Unnamed: 0 Pathway text  Nodes integer  Edges integer  \
# 0           0     aac00010             26             43
# 1           1     aac00020             27             52
# 2           2     aac00030             26             53
# 3           3     aac00040             20             28
# 4           4     aac00051             15             33
#
#    Connected Components integer  Network Diameter integer  \
# 0                             2                         7
# 1                             2                        10
# 2                             2                         6
# 3                             1                         8
# 4                             1                         4
#
#    Network Radius integer  Shortest Path integer  \
# 0                       1                    211
# 1                       1                    226
# 2                       1                    202
# 3                       1                     65
# ...

# %%
plt.scatter(df.iloc[:,2],df.iloc[:,3])
plt.xlabel(df.columns[2])
plt.ylabel(df.columns[3])
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import seaborn as sns

# %%
df = pd.read_csv('dataset_MLproject.csv')

# Use only first 4 numeric columns for a pairplot (for clarity)
sns.pairplot(df.iloc[:, :4].sample(1000))  # sample to avoid overplotting
plt.show()
